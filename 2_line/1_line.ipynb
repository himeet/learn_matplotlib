# %%
# 折线图
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def plot():
    x = np.linspace(-10, 10, 5)  # -10到10等距离分成100份
    y = x**2
    plt.plot(x, y)
    plt.show()
    

def main():
    plot()
    

if __name__ == '__main__':
    main()
